# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('banklist.csv')

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
#df=pd.read_excel('Tentative Course List (Jan - Apr 2026).xlsx')

# %%
df.head()#first 5 rows
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
df.tail()#last 5 rows
# Out:
#                              Bank Name        City  ST   CERT  \
# 546                 Superior Bank, FSB    Hinsdale  IL  32646
# 547                Malta National Bank       Malta  OH   6629
# 548    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 549  National State Bank of Metropolis  Metropolis  IL   3815
# 550                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date Updated Date
# 546                Superior Federal, FSB    27-Jul-01    19-Aug-14
# 547                    North Valley Bank     3-May-01    18-Nov-02
# 548  Southern New Hampshire Bank & Trust     2-Feb-01    18-Feb-03
# 549              Banterra Bank of Marion    14-Dec-00    17-Mar-05
# 550                   Bank of the Orient    13-Oct-00    17-Mar-05

# %%
df.shape#row and col
# Out:
# (551, 7)

# %%
df.info()#Col names, dtypes etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              551 non-null    object
#  1   City                   551 non-null    object
#  2   ST                     551 non-null    object
#  3   CERT                   551 non-null    int64
#  4   Acquiring Institution  551 non-null    object
#  5   Closing Date           551 non-null    object
#  6   Updated Date           551 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 30.3+ KB

# %%
df.describe()# Summary stats numeric
# Out:
#                CERT
# count    551.000000
# mean   31729.392015
# std    16449.761311
# min       91.000000
# 25%    20315.000000
# 50%    32218.000000
# 75%    35375.500000
# max    58701.000000

# %%
df.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# dtype: object

# %%
df.isnull()
# Out:
#      Bank Name   City     ST   CERT  Acquiring Institution  Closing Date  \
# 0        False  False  False  False                  False         False
# 1        False  False  False  False                  False         False
# 2        False  False  False  False                  False         False
# 3        False  False  False  False                  False         False
# 4        False  False  False  False                  False         False
# ..         ...    ...    ...    ...                    ...           ...
# 546      False  False  False  False                  False         False
# 547      False  False  False  False                  False         False
# 548      False  False  False  False                  False         False
# 549      False  False  False  False                  False         False
# 550      False  False  False  False                  False         False
#
#      Updated Date
# 0           False
# 1           False
# 2           False
# ...

# %%
df.isnull().sum()
# Out:
# Bank Name                0
# City                     0
# ST                       0
# CERT                     0
# Acquiring Institution    0
# Closing Date             0
# Updated Date             0
# dtype: int64

# %%
df.dropna(inplace=True) # Drop missing rows

# %%
#df.fillna(0, inplace=True)
#not using as there were no null values

# %%
df.duplicated().sum() #Checking for duplicates
# Out:
# np.int64(0)

# %%
df.rename(columns={'Updated Date':'New Date'})#not making permanent change
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
df['CERT'] = df['CERT'].astype(float)

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
#undoing float conversionn of cert
df['CERT'] = df['CERT'].astype(int)

# %%
df
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
df[['ST']]
# Out:
#      ST
# 0    IL
# 1    WI
# 2    LA
# 3    UT
# 4    IL
# ..   ..
# 546  IL
# 547  OH
# 548  NH
# 549  IL
# 550  HI
#
# [551 rows x 1 columns]

# %%
df[['Bank Name', 'ST']]
# Out:
#                                              Bank Name  ST
# 0                                  Fayette County Bank  IL
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...  WI
# 2                                       First NBC Bank  LA
# 3                                        Proficio Bank  UT
# 4                        Seaway Bank and Trust Company  IL
# ..                                                 ...  ..
# 546                                 Superior Bank, FSB  IL
# 547                                Malta National Bank  OH
# 548                    First Alliance Bank & Trust Co.  NH
# 549                  National State Bank of Metropolis  IL
# 550                                   Bank of Honolulu  HI
#
# [551 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
df.loc[df['City'] == 'New York']
# Out:
#                 Bank Name      City  ST   CERT Acquiring Institution  \
# 333  The Park Avenue Bank  New York  NY  27096  Valley National Bank
# 334    LibertyPointe Bank  New York  NY  58071  Valley National Bank
#
#     Closing Date Updated Date
# 333    12-Mar-10    23-Aug-12
# 334    11-Mar-10    23-Aug-12

# %%
df['ST'].unique()
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %%
df['ST'].nunique#Total no of cities
# Out:
# <bound method IndexOpsMixin.nunique of 0      IL
# 1      WI
# 2      LA
# 3      UT
# 4      IL
#        ..
# 546    IL
# 547    OH
# 548    NH
# 549    IL
# 550    HI
# Name: ST, Length: 551, dtype: object>

# %%
df.dropna()
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
df.dropna(axis=1)
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
df.dropna(thresh=2)
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...

# %%
df['CERT'].mean()#cert is just an identifier here, and there is no need for this, but just for practice
# Out:
# np.float64(31729.392014519057)

# %%
df.groupby("Bank Name")

# %%
df.std
# Out:
# <bound method DataFrame.std of                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 546                                 Superior Bank, FSB            Hinsdale
# 547                                Malta National Bank               Malta
# 548                    First Alliance Bank & Trust Co.          Manchester
# 549                  National State Bank of Metropolis          Metropolis
# 550                                   Bank of Honolulu            Honolulu
#
# ...
