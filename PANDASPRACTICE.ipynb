# %% [markdown]
# 24csu246

# %%
import pandas as pd
import numpy as np

# %% [raw]
# Create a pandas Series my_series with the following data: [10, 20, 30, 40, 50]. The index
# should be ['A', 'B', 'C', 'D', 'E']

# %%
series=[10,20,30,40,50]
my_series=pd.DataFrame(series,index=['A', 'B', 'C', 'D', 'E'])

# %%
my_series
# Out:
#     0
# A  10
# B  20
# C  30
# D  40
# E  50

# %% [markdown]
# Print the values and index of my_series

# %%
print(my_series.index)
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
print(my_series.values)
# Out:
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]]

# %% [raw]
# Access and print the value at index 'C' in my_series

# %%
print(my_series.loc['C'])
# Out:
# 0    30
# Name: C, dtype: int64

# %%
my_series[my_series.index == 'C']
# Out:
#     0
# C  30

# %% [markdown]
# Create a pandas DataFrame my_dataframe with the following data:
# Name Age City
# 0 Alice 25 Paris
# 1 Bob 30 Tokyo
# 2 Claire 22 Rome
# 3 Dave 28 Oslo

# %%
name=['Alice', 'Bob', 'Claire', 'Dave']
age=[25, 30, 22, 28]
city=['Paris', 'Tokyo', 'Rome', 'Oslo']
d={'Name': name,'Age': age,'City':city }
my_dataframe=pd.DataFrame(d)

# %%
my_dataframe
# Out:
#      Name  Age   City
# 0   Alice   25  Paris
# 1     Bob   30  Tokyo
# 2  Claire   22   Rome
# 3    Dave   28   Oslo

# %% [raw]
# Print the first two rows of `my_dataframe`

# %%
print(my_dataframe[0:2])
# Out:
#     Name  Age   City
# 0  Alice   25  Paris
# 1    Bob   30  Tokyo

# %% [raw]
# Add a new row to `my_dataframe` with the data: ['Eva', 27, 'New York']

# %%
my_series=pd.concat([my_series,pd.Series(['Eva', 27, 'New York'],['F','G','H'])])

# %%
my_series
# Out:
#           0
# A        10
# B        20
# C        30
# D        40
# E        50
# F       Eva
# G        27
# H  New York

# %% [raw]
# Access and print the 'Age' column of `my_dataframe`.

# %%
my_dataframe['Age']
# Out:
# 0    25
# 1    30
# 2    22
# 3    28
# Name: Age, dtype: int64

# %% [raw]
# Mean of age

# %%
print("Mean of age is: ",my_dataframe['Age'].mean())
# Out:
# Mean of age is:  26.25

# %% [raw]
# Filter `my_dataframe` to show only the rows where the age is greater than or equal to 25.

# %%
#for i in my_dataframe:
# Out:
# Name
# Age
# City

# %%
my_dataframe[my_dataframe['Age'] >=25]
# Out:
#     Name  Age   City
# 0  Alice   25  Paris
# 1    Bob   30  Tokyo
# 3   Dave   28   Oslo
