# %% [markdown]
# ### FUNCTIONS

# %%
def avg(n1,n2,n3):
    print((n1+n2+n3)/3)
print(avg(1,2,3))
# Out:
# 2.0
# None

# %%
def avg(n1,n2,n3):
    print((n1+n2+n3)/3)
avg(1,2,3)
# Out:
# 2.0

# %% [markdown]
# Without return print shows output as none
# Do formal and actual parameters

# %%
a(10,20,50)
# Out:
# hello

# %%
def a(n,m,b):
    print("hello")

# %% [markdown]
# in notebook , position doesn't matter when you ran the cell does

# %%
def abc(q1,q2,q3=10):
    return(q1+q2/q3)

# %%
abc(10,25,40)
# Out:
# 10.625

# %%
abc(40,10,25)
# Out:
# 40.4

# %%
abc(40,25,10)
# Out:
# 42.5

# %%
abc(40,25)
# Out:
# 42.5
